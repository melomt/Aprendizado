# %%
from kagglehub import kagglehub
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from kagglehub import kagglehub
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
# Download latest version
path = kagglehub.dataset_download("dell4010/wine-dataset")

print("/home/matheusjm/Documentos/github/mycodes/aprendizadodemaquina", path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Download latest version
# ----> 2 path = kagglehub.dataset_download("dell4010/wine-dataset")
#       4 print("/home/matheusjm/Documentos/github/mycodes/aprendizadodemaquina", path)
#
# NameError: name 'kagglehub' is not defined
